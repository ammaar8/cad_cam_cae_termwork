# %%
import cad_cli
cad_cli.cad.SHOW_TRANFORM_MATRIX = False
cad_cli.set_points([(1,1), (3,1), (3,3), (1,3)])

# %%
cad_cli.main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a4881de6ffe6> in <module>
# ----> 1 cad_cli.main()
#
# ~/Workspace/Programming/College: CADME/cad_cli.py in main()
#      42         global points
#      43         fig, ax = plt.subplots(1)
# ---> 44         cad.plot(ax, points)
#      45         plt.show(block=False)
#      46         while True:
#
# ~/Workspace/Programming/College: CADME/cad.py in plot(ax, points)
#      41         ax.clear()
#      42         ax.add_patch(Polygon(points))
# ---> 43         ax.scatter(*list(zip(*points)), 'r')
#      44         ax.set_xticks(np.arange(-5, 5+1, 1))
#      45         ax.set_yticks(np.arange(-5, 5+1, 1))
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...
